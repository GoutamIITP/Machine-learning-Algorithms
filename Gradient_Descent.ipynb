# %% [markdown]
# Name = Goutam Kumar Sah
#
# Roll Number = 2312res271
#
# # Experiment No = 6
#
# Title = Logistic Regression
#
# Aim = Implementation of Gradient Descent Algorithm

# %% [markdown]
# # Theory

# %% [markdown]
# The Gradient Descent algorithm is an optimization technique used to minimize a function (such as the cost function in machine learning). In the context of linear regression, gradient descent finds the optimal values for the model parameters (slope
# 𝑚
# m and intercept
# 𝑏
# b) to minimize the Mean Squared Error (MSE) between the predicted and actual values.
#
# Here’s a step-by-step breakdown of how the Gradient Descent algorithm works:
#
# 1. Initialize Parameters
#   * Start with initial values for
# 𝑚
# m (slope) and
# 𝑏
# b (intercept), usually set to 0.
#
#  * Set a learning rate
# 𝛼
# α, which controls how large each update step is.
#
# 2. Calculate Predictions
#  * Calculate the Mean Squared Error (MSE) to evaluate how far the predictions are from the actual values:
# MSE
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑦
# 𝑖
# −
# 𝑦
# pred
# 𝑖
# )
# 2
#
# ![image.png](data:image/png;base64,...)
#
# 4. Compute the Gradient (Partial Derivatives)
#
#   * Calculate the gradient of the MSE with respect to
# 𝑚
# m and
# 𝑏
# b, which tells us the direction and rate of change of the error:
#
# ![image.png](data:image/png;base64,...)
#
#   * Adjust
# 𝑚
# m and
# 𝑏
# b in the direction that reduces the error, using the gradients and the learning rate:
#
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt

# %%
X,y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1,noise=80,random_state=13)

# %%
X = X.flatten()

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X.reshape(-1,1)),color='red')

# %% [markdown]
# By Using Gradient Descent

# %%
def gradient_decent(X,y):
  m_curr = b_curr = 0
  iterations = 10
  n = len(X)
  learning_rate = 0.001
  for i in range(iterations):
    y_predicted = m_curr * X + b_curr
    cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
    md = -(2/n)*sum(X*(y-y_predicted))
    bd = -(2/n)*sum(y-y_predicted)
    m_curr = m_curr - learning_rate * md
    b_curr = b_curr - learning_rate * bd
    print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
pass

gradient_decent(X,y)
# Out:
# m 0.056082822291710806, b 0.06989664249515819, cost 5481.575327492961 iteration 0
# m 0.11211402090133649, b 0.13964090994541056, cost 5473.551276757576 iteration 1
# m 0.1680936630981528, b 0.20923311868223224, cost 5465.554265693365 iteration 2
# m 0.22402181603735666, b 0.27867358438934403, cost 5457.584191077418 iteration 3
# m 0.2798985467602847, b 0.3479626221040335, cost 5449.640950098552 iteration 4
# m 0.33572392219463115, b 0.41710054621847353, cost 5441.724440355632 iteration 5
# m 0.3914980091546656, b 0.48608767048103785, cost 5433.834559855917 iteration 6
# m 0.44722087434144975, b 0.554924307997614, cost 5425.971207013413 iteration 7
# m 0.5028925843430546, b 0.6236107712329143, cost 5418.134280647227 iteration 8
# m 0.5585132056347762, b 0.6921473720117827, cost 5410.3236799799215 iteration 9

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Generate data
X, y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=13)
X = X.flatten()  # Flatten X to a 1D array if necessary

# Gradient descent function with plotting
def gradient_descent(X, y):
    m_curr = b_curr = 0  # Initial values for slope and intercept
    rate = 0.01          # Learning rate
    n = len(X)           # Number of samples

    # Plot original data points
    plt.figure(figsize=(8, 6))
    plt.scatter(X, y, color='red', marker='+', linewidth=5)

    # Gradient descent iterations
    for i in range(10000):
        y_predicted = m_curr * X + b_curr
        if i % 500 == 0:  # Plot every 500 iterations for clarity
            plt.plot(X, y_predicted, color='green', alpha=0.3)

        # Calculate gradients
        md = -(2/n) * sum(X * (y - y_predicted))
        yd = -(2/n) * sum(y - y_predicted)

        # Update parameters
        m_curr = m_curr - rate * md
        b_curr = b_curr - rate * yd

    # Final line of best fit
    plt.plot(X, m_curr * X + b_curr, color='blue')
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title("Gradient Descent Linear Regression")
    plt.show()
    return m_curr, b_curr
# Run the gradient descent function
gradient_descent(X, y)
# Out:
# (78.3506366794738, 26.15963284313284)

# %% [markdown]
# To calculate the error in gradient descent, you can use the Mean Squared Error (MSE), which is a common error metric for regression problems. MSE is calculated as:
#
# ![image.png](data:image/png;base64,...)
#
# where:
#  * y
# i
# ​
#   is the actual value,
# 𝑦
# ^
# 𝑖
#  * y^
# ​
#   i
# ​ is the predicted value,
#  * 𝑛
# n is the number of data points.

# %%
import numpy as np

# Assuming m_curr and b_curr are the final values obtained from gradient descent
# and X, y are the data points
def calculate_mse(X, y, m, b):
    n = len(X)
    y_predicted = m * X + b
    mse = (1/n) * sum((y - y_predicted) ** 2)
    return mse

# Use the values obtained from gradient descent
final_m = 78.3506366794738  # Final slope from gradient descent
final_b = 26.15963284313284  # Final intercept from gradient descent

# Calculate the MSE with the final values
mse = calculate_mse(X, y, final_m, final_b)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 2370.277658503745
