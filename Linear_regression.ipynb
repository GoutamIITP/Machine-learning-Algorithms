# %% [markdown]
# Name = Goutam Kumar Sah
#
# Roll Number = 2312res271
#
# Experiment No = 4
#
# Title = Linear Regression
#
# Aim = Implementation of Linear Regression Algorithm

# %% [markdown]
# # Theory

# %% [markdown]
# Linear regression is a fundamental statistical and machine learning technique used to model the relationship between a dependent variable (target) and one or more independent variables (features). It’s primarily used for predictive modeling and assessing the strength of relationships between variables. In simple linear regression, the model assumes a linear relationship between a single feature (x) and the target variable (y), typically expressed as:
#
#    ![image.png](data:image/png;base64,...)
#
# where
# 𝑚
# m (slope) represents the change in
# 𝑦
# y for a unit change in
# 𝑥
# x, and
# 𝑐
# c (intercept) is the value of
# 𝑦
# y when
# 𝑥
# x is zero. In multiple linear regression, where multiple features are involved, the equation generalizes to:
#
# ![image.png](data:image/png;base64,...)
#
# where
# 𝑏
# 0
# ,
# 𝑏
# 1
# ,
# …
# ,
# 𝑏
# 𝑛
# b
# 0
# ​
#  ,b
# 1
# ​
#  ,…,b
# n
# ​
#   are the coefficients learned from data, determining the relationship between each feature and the target variable.
#
# The goal of linear regression is to find the best-fitting line through data points by minimizing the sum of squared errors (SSE) between predicted and actual values. This method, known as Ordinary Least Squares (OLS), ensures that the predicted line captures the trend in data with minimal error.
#
# Linear regression is widely used in applications such as forecasting, risk assessment, and trend analysis due to its simplicity and interpretability. However, it assumes linearity, homoscedasticity (constant variance of errors), independence of observations, and normally distributed errors, which may not always hold in real-world scenarios.
#
# Despite its limitations, linear regression remains a foundational tool in predictive analytics and machine learning, serving as a benchmark model and a stepping stone to more complex methods.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("")
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# By using Manual code

# %%
#siple linear regression
from sklearn.metrics import mean_squared_error
class MY_LR:
  def __init__(self):
    self.m = None
    self.b = None

  def fit(self, X_train, y_train):
    num = 0
    den = 0

    for i in range(X_train.shape[0]):
      num = num + ((X_train[i] - X_train.mean()) * (y_train[i] - y_train.mean()))
      den = den + ((X_train[i] - X_train.mean()) * (X_train[i] - X_train.mean()))

    self.m = num/den
    self.b = y_train.mean() - (self.m * X_train.mean())
    print(self.m)
    print(self.b)

  def predict(self, X_test):
    return self.m * X_test + self.b

  def evaluate(self, X_test, y_test):
    y_pred = self.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    print(f"Mean Squared Error: {mse}")
    return mse

# %%
model = MY_LR()
model.fit(X_train,y_train)
predict = model.predict(X_test)
model.evaluate(X_test,y_test)
# Out:
# 0.5579519734250721
# -0.8961119222429152
# Mean Squared Error: 0.12129235313495523
# 0.12129235313495523

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R²): {r2}")
# Out:
# Mean Squared Error (MSE): 0.12129235313495523
# Mean Absolute Error (MAE): 0.2884710931878174
# R-squared (R²): 0.7807301475103842

# %% [markdown]
# # By using Sklearn Library

# %%
X = df.iloc[:,0:1]
Y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R²): {r2}")
# Out:
# Mean Squared Error (MSE): 0.12129235313495523
# Mean Absolute Error (MAE): 0.2884710931878174
# R-squared (R²): 0.7807301475103842

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='black')
plt.xlabel('CGPA')
plt.ylabel('package (in LPA)')
# Out:
# Text(0, 0.5, 'package (in LPA)')
