# %% [markdown]
# Title = Logistic Regression
#
# Aim = Implementation of logistic regression

# %% [markdown]
# Logistic Regression is a statistical algorithm used primarily for binary classification tasks, where the goal is to predict one of two possible outcomes (e.g., yes/no, 0/1, pass/fail). Unlike linear regression, which predicts continuous outcomes, logistic regression predicts the probability that a given input belongs to a certain class, making it ideal for classification problems.
#
# Key Concepts:
#
#
# *  Logit Function: The key idea behind logistic regression is the logit function, which is the natural logarithm of the odds (the ratio of the probability of the event occurring to the probability of it not occurring).
#
# ![image.png](data:image/png;base64,...)
#
#
# where 𝑝 is the probability of the outcome being 1.
#
#
# *   Sigmoid Function: The output of logistic regression is transformed into a
# a probability using sigmoid (or logistic ) Function:
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#   where
# 𝑧
# =
# 𝛽
# 0
# +
# 𝛽
# 1
# 𝑥
# 1
# +
# ⋯
# +
# 𝛽
# 𝑛
# 𝑥
# 𝑛
# z=β
# 0
# ​
#  +β
# 1
# ​
#  x
# 1
# ​
#  +⋯+β
# n
# ​
#  x
# n
# ​
#  , and
# 𝛽
# 𝑖
# β
# i
# ​
#   are the model coefficients (parameters).
#
# *   Binary Classification: Logistic regression models binary outcomes by predicting whether the probability
# 𝑝
# p is greater than or less than a threshold, usually 0.5. If p>0.5, the model predicts class 1; otherwise, it predicts class 0.
#
# Applications:
# * Healthcare: Used to predict disease occurrence (e.g., whether a patient has a disease based on diagnostic measures).
# * Finance: Applied in credit scoring, where it predicts whether a borrower will default on a loan.
# * Marketing: Helps classify customers into different categories (e.g., likely to purchase or not based on browsing history).

# %% [markdown]
# # Logistic Regreession Algorithm work
#
# The logistic regression model transforms the linear regression function continuous value output into categorical value output using a sigmoid function, which maps any real-valued set of independent variables input into a value between 0 and 1. This function is known as the logistic function.
#
# ![image.png](data:image/png;base64,...)
#
# and the dependent variable is Y having only binary value i.e. 0 or 1.
# ![image.png](data:image/png;base64,...)
#
# then, apply the multi-linear function to the input variables X.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# whatever we discussed above is the linear regression.
#
# Sigmoid Function
#
# Now we use the sigmoid function where the input will be z and we find the probability between 0 and 1. i.e. predicted y.
#
# ![image.png](data:image/png;base64,...)
#
# As shown above, the figure sigmoid function converts the continuous variable data into the probability i.e. between 0 and 1.
#
# ![image.png](data:image/png;base64,...)
#
# where the probability of being a class can be measured as:
#
# ![image.png](data:image/png;base64,...)
#
# #Logistic Regression Equation
#
# The odd is the ratio of something occurring to something not occurring. it is different from probability as the probability is the ratio of something occurring to everything that could possibly occur. so odd will be:
#
# ![image.png](data:image/png;base64,...)
#
# then the final logistic regression equation will be:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Platform = Google colab

# %% [markdown]
# Manual code

# %%
#Algorithm
import numpy as np
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

class LogisticRegression:
  def __init__(self, learning_rate=0.01, num_iterations=1000):
    self.learning_rate = learning_rate
    self.num_iterations = num_iterations
    self.weights = None
    self.bias = None

  def fit(self, X, y):
    num_samples, num_features = X.shape
    self.weights = np.zeros(num_features)
    self.bias = 0

    for _ in range(self.num_iterations):
      linear_model = np.dot(X, self.weights) + self.bias
      predictions = sigmoid(linear_model)

      # Compute gradients
      dw = (1 / num_samples) * np.dot(X.T, (predictions - y))
      db = (1 / num_samples) * np.sum(predictions - y)

      # Update parameters
      self.weights -= self.learning_rate * dw
      self.bias -= self.learning_rate * db

  def predict(self, X):
    linear_model = np.dot(X, self.weights) + self.bias
    y_pred = sigmoid(linear_model)
    class_pred = [0 if y<=0.5 else 1 for y in y_pred]
    return class_pred

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets

ab = datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf = LogisticRegression(learning_rate=0.01, num_iterations=1000)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

def accuracy(y_pred, y_test):
  accuracy = np.sum(y_pred == y_test) / len(y_test)
  return accuracy

acc = accuracy(y_pred, y_test)
print(acc)
# Out:
# 0.8859649122807017
# <ipython-input-32-c17de5e6404d>:4: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))

# %% [markdown]
# By using sk learn library

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
# Train the Logistic Regression model
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
# Evaluate the model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 96.49%
