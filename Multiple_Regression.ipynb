# %% [markdown]
# Name = Goutam Kumar Sah
#
# Roll Number = 2312res271
#
# Experiment No = 5
#
# Title = Multiple Regression
#
# Aim = Implementation of Multiple Regression Algorithm

# %% [markdown]
# # Theory

# %% [markdown]
# Multiple regression is an extension of simple linear regression that models the relationship between a dependent variable and two or more independent variables. In multiple regression, the goal is to predict the outcome variable by considering several predictors, capturing the impact of each one on the target. The equation for multiple regression is:
#
# ![image.png](data:image/png;base64,...)
#
# where:
#
#    * Y is the dependent variable.
#
#    * b is the intercept, representing the value of
# 𝑌
# Y when all
# 𝑋
# X values are zero.
#
# * m
# 1
# ​
#  ,m
# 2
# ​
#  ,...,m
# n
# ​
#   are the coefficients or weights of each independent variable
# 𝑋
# 1
# ,
# 𝑋
# 2
# ,
# .
# .
# .
# ,
# 𝑋
# 𝑛
# X
# 1
# ​
#  ,X
# 2
# ​
#  ,...,X
# n
# ​
#  , showing the relationship between each predictor and the outcome variable.
#
# The coefficients are estimated by minimizing the cost function, typically using Mean Squared Error (MSE). Multiple regression uses methods like gradient descent or normal equations to find the optimal values for these coefficients, aiming to reduce the residuals or errors between predicted and actual values.
#
# This type of regression is particularly useful in scenarios where a single predictor isn’t sufficient to make accurate predictions, and several variables collectively influence the outcome. For example, in predicting house prices, factors like location, number of bedrooms, square footage, and age of the house might all be relevant.
#
# Assumptions in multiple regression include linearity (a linear relationship between each predictor and the target), independence of observations, homoscedasticity (constant variance of residuals), and no multicollinearity (independent variables should not be highly correlated with each other).
#
# Multiple regression helps reveal the individual impact of each variable while controlling for others, allowing us to understand complex relationships. The model’s performance can be evaluated using metrics like R-squared and Adjusted R-squared, which indicate how well the predictors explain the variance in the target variable.

# %%
import numpy as np
from sklearn.datasets import load_diabetes

# %%
X,y = load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# By using manual code algorithm implementation

# %%
class My_LR:
    def __init__(self):
        self.coef_ = None
        self.intercept_ = None

    def fit(self,X_train,y_train):
        X_train = np.insert(X_train,0,1,axis=1)

        # calculate coefficients using normal equations
        betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
        self.intercept_ = betas[0]
        self.coef_ = betas[1:]


    def predict(self,X_test):
        y_pred = np.dot(X_test,self.coef_) + self.intercept_
        return y_pred

# %%
model = My_LR()
model.fit(X_train,y_train)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R²): {r2}")
# Out:
# Mean Squared Error (MSE): 3094.4566715660653
# Mean Absolute Error (MAE): 45.21303419046907
# R-squared (R²): 0.43993386615689634

# %% [markdown]
# By Using skLearn library

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R²): {r2}")
# Out:
# Mean Squared Error (MSE): 3094.4566715660626
# Mean Absolute Error (MAE): 45.213034190469024
# R-squared (R²): 0.4399338661568968
